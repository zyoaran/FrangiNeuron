# %% [markdown]
# The scripts included in this notebook are prepared for the purpose of reproducing the research results.
#
# Code authored by X. and X.

# %%
! git clone https://github.com/browarsoftware/FrangiNeuron.git
# Out:
# Cloning into 'FrangiNeuron'...
# remote: Enumerating objects: 170, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 170 (delta 85), reused 164 (delta 85), pack-reused 0
# Receiving objects: 100% (170/170), 30.30 MiB | 19.55 MiB/s, done.
# Resolving deltas: 100% (85/85), done.

# %% [markdown]
# Required additional libraries not installed in Colab

# %%
! pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.1 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.16.1

# %% [markdown]
# Setting the system path to the code sources

# %%
PATH = './FrangiNeuron'

import sys
sys.path.append(PATH + "/sources/")

# %% [markdown]
# Defining a model using FrangiLayers blocks

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate
from tensorflow.keras.models import Sequential, Model
import tensorflow_addons as tfa

from random import randint
from numpy import random

import cv2

# code implementing augmentation
import augmenter
# some utility function
import utils
# implementation of FrangiLayer and auxiliary functions
from frangi_module import FrangiLayer, ScaleLayer, Scaling01

# model definition
inp = Input(shape=(None, None, 1))
abc_list = []

for sigma in [1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4, 5, 6, 7, 8, 9, 10]:
    ml = FrangiLayer(sigma=sigma)(inp)
    ml = ScaleLayer()(ml)
    abc_list.append(ml)

x = keras.layers.Maximum()(abc_list)
x = Scaling01()(x)
model = Model(inp, x)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  1)]
#
#  frangi_layer (FrangiLayer)     (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_1 (FrangiLayer)   (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_2 (FrangiLayer)   (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_3 (FrangiLayer)   (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_4 (FrangiLayer)   (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_5 (FrangiLayer)   (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_6 (FrangiLayer)   (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_7 (FrangiLayer)   (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_8 (FrangiLayer)   (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_9 (FrangiLayer)   (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_10 (FrangiLayer)  (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_11 (FrangiLayer)  (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_12 (FrangiLayer)  (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_13 (FrangiLayer)  (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_14 (FrangiLayer)  (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_15 (FrangiLayer)  (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_16 (FrangiLayer)  (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_17 (FrangiLayer)  (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  frangi_layer_18 (FrangiLayer)  (None, None, None,   2           ['input_1[0][0]']
#                                 1)
#
#  scale_layer (ScaleLayer)       (None, None, None,   1           ['frangi_layer[0][0]']
#                                 1)
#
#  scale_layer_1 (ScaleLayer)     (None, None, None,   1           ['frangi_layer_1[0][0]']
#                                 1)
#
#  scale_layer_2 (ScaleLayer)     (None, None, None,   1           ['frangi_layer_2[0][0]']
#                                 1)
#
#  scale_layer_3 (ScaleLayer)     (None, None, None,   1           ['frangi_layer_3[0][0]']
#                                 1)
#
#  scale_layer_4 (ScaleLayer)     (None, None, None,   1           ['frangi_layer_4[0][0]']
#                                 1)
#
#  scale_layer_5 (ScaleLayer)     (None, None, None,   1           ['frangi_layer_5[0][0]']
#                                 1)
#
#  scale_layer_6 (ScaleLayer)     (None, None, None,   1           ['frangi_layer_6[0][0]']
#                                 1)
#
#  scale_layer_7 (ScaleLayer)     (None, None, None,   1           ['frangi_layer_7[0][0]']
#                                 1)
#
#  scale_layer_8 (ScaleLayer)     (None, None, None,   1           ['frangi_layer_8[0][0]']
#                                 1)
#
#  scale_layer_9 (ScaleLayer)     (None, None, None,   1           ['frangi_layer_9[0][0]']
#                                 1)
#
#  scale_layer_10 (ScaleLayer)    (None, None, None,   1           ['frangi_layer_10[0][0]']
#                                 1)
#
#  scale_layer_11 (ScaleLayer)    (None, None, None,   1           ['frangi_layer_11[0][0]']
#                                 1)
#
#  scale_layer_12 (ScaleLayer)    (None, None, None,   1           ['frangi_layer_12[0][0]']
#                                 1)
#
#  scale_layer_13 (ScaleLayer)    (None, None, None,   1           ['frangi_layer_13[0][0]']
#                                 1)
#
#  scale_layer_14 (ScaleLayer)    (None, None, None,   1           ['frangi_layer_14[0][0]']
#                                 1)
#
#  scale_layer_15 (ScaleLayer)    (None, None, None,   1           ['frangi_layer_15[0][0]']
#                                 1)
#
#  scale_layer_16 (ScaleLayer)    (None, None, None,   1           ['frangi_layer_16[0][0]']
#                                 1)
#
#  scale_layer_17 (ScaleLayer)    (None, None, None,   1           ['frangi_layer_17[0][0]']
#                                 1)
#
#  scale_layer_18 (ScaleLayer)    (None, None, None,   1           ['frangi_layer_18[0][0]']
#                                 1)
#
#  maximum (Maximum)              (None, None, None,   0           ['scale_layer[0][0]',
#                                 1)                                'scale_layer_1[0][0]',
#                                                                   'scale_layer_2[0][0]',
#                                                                   'scale_layer_3[0][0]',
#                                                                   'scale_layer_4[0][0]',
#                                                                   'scale_layer_5[0][0]',
#                                                                   'scale_layer_6[0][0]',
#                                                                   'scale_layer_7[0][0]',
#                                                                   'scale_layer_8[0][0]',
#                                                                   'scale_layer_9[0][0]',
#                                                                   'scale_layer_10[0][0]',
#                                                                   'scale_layer_11[0][0]',
#                                                                   'scale_layer_12[0][0]',
#                                                                   'scale_layer_13[0][0]',
#                                                                   'scale_layer_14[0][0]',
#                                                                   'scale_layer_15[0][0]',
#                                                                   'scale_layer_16[0][0]',
#                                                                   'scale_layer_17[0][0]',
#                                                                   'scale_layer_18[0][0]']
#
#  scaling01 (Scaling01)          (None, None, None,   0           ['maximum[0][0]']
#                                 1)
#
# ==================================================================================================
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Settings needed for localization of training and test data

# %%
# chooosing image dedicated to trainng phase
# a single image is sufficient to train the model effectively
img_id = 3

DATA_NAME = 'brain'
DATA_FOLDER = '/data/' + DATA_NAME + '/images/'
MANUAL_FOLDER = '/data/' + DATA_NAME + '/manual/'
FILE_FILTER = '*.tif'
TRAINING_IMAGES = PATH + DATA_FOLDER + str(img_id) + FILE_FILTER
MANUAL_IMAGES = PATH + MANUAL_FOLDER + str(img_id) + FILE_FILTER

LOC_FOR_WEIGHTS = PATH + '/weights/model_weights.' + DATA_NAME + '.{epoch:03d}.hdf5'
LOC_FOR_MODELS = PATH + "/models/" + "model.best_" + str(img_id) + "." + DATA_NAME + ".h5"

# %% [markdown]
# Training the model

# %%
from tensorflow.keras.optimizers import Adam
from keras import losses
from glob import glob

# Callback function
my_callbacks = [
    tf.keras.callbacks.ModelCheckpoint(filepath=LOC_FOR_WEIGHTS)
]

# selecting training data consisted of raw image + reference manual
train_data = list(zip(sorted(glob(TRAINING_IMAGES)), sorted(glob(MANUAL_IMAGES))))
                      
# batch size settings
batch_size = 16
#  model compilation
model.compile(optimizer=Adam(learning_rate=1e-2), loss=losses.binary_crossentropy, metrics=['accuracy'])

history = model.fit(augmenter.gen(train_data, au=True), epochs=50, verbose=True,
                    steps_per_epoch=100 * len(train_data) // batch_size,
                    callbacks=my_callbacks)

# Save model weights
model.save(LOC_FOR_MODELS)
# Out:
# Epoch 1/50
# 6/6 [==============================] - 20s 261ms/step - loss: 0.5889 - accuracy: 0.8340
# Epoch 2/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.5839 - accuracy: 0.8344
# Epoch 3/50
# 6/6 [==============================] - 2s 257ms/step - loss: 0.6531 - accuracy: 0.8186
# Epoch 4/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.5600 - accuracy: 0.8354
# Epoch 5/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.5839 - accuracy: 0.8255
# Epoch 6/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.6931 - accuracy: 0.8004
# Epoch 7/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.5405 - accuracy: 0.8368
# Epoch 8/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.5518 - accuracy: 0.8355
# Epoch 9/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.5146 - accuracy: 0.8469
# Epoch 10/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.6568 - accuracy: 0.8085
# Epoch 11/50
# 6/6 [==============================] - 2s 262ms/step - loss: 0.5906 - accuracy: 0.8247
# Epoch 12/50
# 6/6 [==============================] - 1s 256ms/step - loss: 0.5493 - accuracy: 0.8332
# Epoch 13/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.5643 - accuracy: 0.8336
# Epoch 14/50
# 6/6 [==============================] - 1s 256ms/step - loss: 0.6126 - accuracy: 0.8188
# Epoch 15/50
# 6/6 [==============================] - 2s 261ms/step - loss: 0.5155 - accuracy: 0.8467
# Epoch 16/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.4525 - accuracy: 0.8616
# Epoch 17/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.6566 - accuracy: 0.8033
# Epoch 18/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.5780 - accuracy: 0.8168
# Epoch 19/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.5951 - accuracy: 0.8193
# Epoch 20/50
# 6/6 [==============================] - 2s 261ms/step - loss: 0.5830 - accuracy: 0.8303
# Epoch 21/50
# 6/6 [==============================] - 2s 260ms/step - loss: 0.6253 - accuracy: 0.8179
# Epoch 22/50
# 6/6 [==============================] - 2s 260ms/step - loss: 0.5300 - accuracy: 0.8424
# Epoch 23/50
# 6/6 [==============================] - 2s 260ms/step - loss: 0.5672 - accuracy: 0.8253
# Epoch 24/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.6566 - accuracy: 0.8068
# Epoch 25/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.6440 - accuracy: 0.8115
# Epoch 26/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.5402 - accuracy: 0.8383
# Epoch 27/50
# 6/6 [==============================] - 2s 257ms/step - loss: 0.4564 - accuracy: 0.8510
# Epoch 28/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.5962 - accuracy: 0.8180
# Epoch 29/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.5912 - accuracy: 0.8181
# Epoch 30/50
# 6/6 [==============================] - 2s 257ms/step - loss: 0.5800 - accuracy: 0.8221
# Epoch 31/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.5511 - accuracy: 0.8283
# Epoch 32/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.5643 - accuracy: 0.8344
# Epoch 33/50
# 6/6 [==============================] - 1s 255ms/step - loss: 0.5095 - accuracy: 0.8472
# Epoch 34/50
# 6/6 [==============================] - 2s 261ms/step - loss: 0.5313 - accuracy: 0.8344
# Epoch 35/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.5850 - accuracy: 0.8205
# Epoch 36/50
# 6/6 [==============================] - 2s 261ms/step - loss: 0.6315 - accuracy: 0.8096
# Epoch 37/50
# 6/6 [==============================] - 2s 257ms/step - loss: 0.6509 - accuracy: 0.7993
# Epoch 38/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.5578 - accuracy: 0.8241
# Epoch 39/50
# 6/6 [==============================] - 2s 260ms/step - loss: 0.6496 - accuracy: 0.8089
# Epoch 40/50
# 6/6 [==============================] - 2s 260ms/step - loss: 0.5809 - accuracy: 0.8249
# Epoch 41/50
# 6/6 [==============================] - 2s 260ms/step - loss: 0.5732 - accuracy: 0.8337
# Epoch 42/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.5740 - accuracy: 0.8206
# Epoch 43/50
# 6/6 [==============================] - 2s 256ms/step - loss: 0.5700 - accuracy: 0.8286
# Epoch 44/50
# 6/6 [==============================] - 2s 263ms/step - loss: 0.5130 - accuracy: 0.8499
# Epoch 45/50
# 6/6 [==============================] - 2s 258ms/step - loss: 0.4117 - accuracy: 0.8706
# Epoch 46/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.5151 - accuracy: 0.8376
# Epoch 47/50
# 6/6 [==============================] - 2s 259ms/step - loss: 0.5666 - accuracy: 0.8301
# Epoch 48/50
# 6/6 [==============================] - 2s 264ms/step - loss: 0.5933 - accuracy: 0.8202
# Epoch 49/50
# 6/6 [==============================] - 2s 261ms/step - loss: 0.5435 - accuracy: 0.8330
# Epoch 50/50
# 6/6 [==============================] - 2s 263ms/step - loss: 0.5103 - accuracy: 0.8428

# %% [markdown]
# Evaluation of model performance on data not used for learning

# %%
from glob import glob
import os
import cv2

# Path to directory with test data
TEST_IMAGES = PATH + DATA_FOLDER + FILE_FILTER
files = glob(TEST_IMAGES)
a = 0
while a < len(files):
    if files[a].find(str(img_id)) > 0:
        trained_image = files.pop(a)
    else:
        a = a + 1

files.append(trained_image)

model.load_weights(LOC_FOR_MODELS)

trial = utils.trialContextManager()

LOC_FOR_RESULTS = './results/'
LOC_FOR_RESULTS_SUB = 'results_' +str(img_id) + '/'

with trial: os.mkdir(LOC_FOR_RESULTS)
with trial: os.mkdir(LOC_FOR_RESULTS + LOC_FOR_RESULTS_SUB)

raw_images = []
segmented_images = []
segmented_images_inv = []
for num, ff in enumerate(files):
    file_name_write = os.path.basename(ff)
    file_path = LOC_FOR_RESULTS
    file_name_read = ff
    image = utils.load_image(file_name_read)
    image = cv2.resize(image, dsize=(image.shape[1], image.shape[0]))

    raw_images.append(image)

    cc = np.expand_dims(image, axis=2)
    cc = np.expand_dims(cc, axis=0)  # / 255.0
    cc = cc.astype(float)

    tt = model.predict(cc)
    fi = tt[0, :, :, 0]
    max_max = np.nanmax(fi)
    fi *= 255.0 / max_max
    fi = fi.astype(np.uint8)

    segmented_images.append(fi)
    segmented_images_inv.append(cv2.bitwise_not(fi))

    if num < len(files) - 1:
      cv2.imwrite(LOC_FOR_RESULTS+ LOC_FOR_RESULTS_SUB + file_name_write, cv2.bitwise_not(fi))

# %% [markdown]
# Visual presentation of how the model works

# %%
import numpy as np
import matplotlib.pyplot as plt

w = 10
h = 10
fig = plt.figure(figsize=(15, 12))
plt.suptitle('Visualization of Frangi Network operation', ha='center', va='baseline', size=16, x=.5, y=.94)
plt.axis('off')
fig.patch.set_facecolor('gray')
fig.patch.set_alpha(0.5)

columns = 3
rows = 3
ax = []
n_files = 3
labels = ['raw input image'] * n_files + ['output after frangi network'] * n_files + ['inverted output for contrast'] * n_files

for i, img in enumerate(raw_images[:n_files] + segmented_images[:n_files] + segmented_images_inv[:n_files]):

    border_h = (5, 5)
    border_v = (5, 5)
    img = np.pad(img, (border_v, border_h), constant_values=0)

    ax = fig.add_subplot(rows, columns, i+1)
    ax.set_title(labels[i] + "\n" + files[i%(n_files+1)].split('/')[-1])
    ax.axis('off')

    plt.imshow(img, cmap='gray')

plt.show()
